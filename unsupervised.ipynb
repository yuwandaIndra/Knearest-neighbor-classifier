# %% [markdown]
# # M Ryan Laksmana Putra
# # 14116108

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('iris.data')

# %%
data.shape
# Out:
# (149, 5)

# %%
data.head()
# Out:
#    5.1  3.5  1.4  0.2         Iris
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
import seaborn as sns

# %%
sns.pairplot(data,diag_kind='5.1',hue='Iris')

# %%
from sklearn.cluster import KMeans
from scipy.stats import zscore

# %%
kmeans=KMeans(n_clusters=5,n_init=15,random_state=2)

# %%
from sklearn.model_selection import train_test_split
X=data.drop('Iris',axis=1)
y=data['Iris']

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_std=sc.fit_transform(X)
y.shape
# Out:
# (149,)

# %%
X.shape
# Out:
# (149, 4)

# %%
y.value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: Iris, dtype: int64

# %%
kmeans.fit(X_std)
# Out:
# KMeans(n_clusters=5, n_init=15, random_state=2)

# %%
centroid=kmeans.cluster_centers_

# %%
c_df=pd.DataFrame(centroid,columns=list(X))
c_df
# Out:
#         5.1       3.5       1.4       0.2
# 0 -0.369898 -1.407618  0.098716 -0.007076
# 1 -0.697007  1.596842 -1.309903 -1.211237
# 2  1.302005  0.188283  1.118069  1.167482
# 3 -1.287389  0.233415 -1.322286 -1.310419
# 4  0.302074 -0.406098  0.542938  0.499616

# %%
# acidity is very low in 0 cluster ,very high in 1 cluster
# average in 1 cluster
# alcohol presentage is different 
# sugar also good feature for different
# citric acid also good feature we also observe in pairplot
#lable 0 has least alcohol quantity 
#lable 1 has higher quality content 
# lable 2 has less than 1 quality

# %%
data.boxplot(column=['0.2'],by='Iris')
# Out:
# <AxesSubplot:title={'center':'0.2'}, xlabel='Iris'>

# %%
ypred=pd.DataFrame(kmeans.labels_)
ypred[0].value_counts()
# Out:
# 4    45
# 2    34
# 3    27
# 1    22
# 0    21
# Name: 0, dtype: int64
